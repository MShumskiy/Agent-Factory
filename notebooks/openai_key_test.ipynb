# %%
from openai import OpenAI
import os

# old deleted key
openai_key = os.getenv("OPENAI_API_KEY")
# new working key
openai_key = "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"
# Explicitly pass your API key
client = OpenAI(api_key=openai_key)


response = client.chat.completions.create(
    model="gpt-4",
    messages=[
        {"role": "user", "content": "Tell me a 10 word story"}
    ],
    max_tokens=50,
)

print(response.choices[0].message.content.strip())
# Out:
# "Lost in woods, found a cabin. Knocked. My childhood self answered."
